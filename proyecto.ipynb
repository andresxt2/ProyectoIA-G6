# %% [markdown]
# # Preprocesamiento de Dataset - GRUPO 6
# ## Integrantes:

# %%
import pandas as pd
import numpy as np
from io import StringIO

# %% [markdown]
# # Análisis Inicial de los Datos
# ## Carga de Datos

# %%
import pandas as pd
import pyreadstat

df = pd.read_spss("EDG_1990_2021.sav")
df
# Out:
#           prov_insc  cant_insc  parr_insc  anio_insc    mes_insc  dia_insc  \
# 0              Loja       Loja       Loja     1990.0       Julio       NaN
# 1              Loja       Loja       Loja     1990.0       Junio       NaN
# 2              Loja       Loja       Loja     1990.0  Septiembre       NaN
# 3             Azuay     Cuenca     Cuenca     1990.0      Agosto       NaN
# 4             Azuay     Cuenca     Cuenca     1990.0      Agosto       NaN
# ...             ...        ...        ...        ...         ...       ...
# 1982276      Manabí       Jama       Jama     2021.0   Diciembre      16.0
# 1982277  Chimborazo     Alausí     Alausí     2021.0       Marzo      23.0
# 1982278      El Oro   El Guabo   El Guabo     2021.0   Noviembre      11.0
# 1982279        Loja  Espíndola    Amaluza     2021.0      Agosto      30.0
# 1982280   Pichincha  Rumiñahui  Sangolquí     2021.0  Septiembre      21.0
#
# ...

# %% [markdown]
# ### Pasos para el Preprocesamiento
# 1. Carga de los datos.
# 2. Obtener una muestra.
# 3. Limpieza de valores nulos.
# 4. Codificación de variables categóricas.

# %%
muestra = df.sample(frac=0.2, random_state=6)
muestra
# Out:
#            prov_insc                        cant_insc   parr_insc  anio_insc  \
# 964041     Pichincha  Distrito Metropolitano de Quito       Quito     2007.0
# 1179522       Guayas                        Guayaquil   Guayaquil     2011.0
# 320584    Chimborazo                         Riobamba       Licto     1996.0
# 1134345       Manabí                            Chone       Chone     2010.0
# 735676     Pichincha  Distrito Metropolitano de Quito       Quito     2003.0
# ...              ...                              ...         ...        ...
# 133009      Imbabura                        Cotacachi     Imantag     1992.0
# 1791778       Guayas                        Guayaquil  Rocafuerte     2020.0
# 517691    Tungurahua                           Ambato      Izamba     1999.0
# 597305   Santa Elena                      Santa Elena     Chanduy     2001.0
# 1661460       Manabí                            Manta      Tarqui     2018.0
#
# ...

# %% [markdown]
# # Se genera un CSV para poder filtrar los campos

# %%
"""
import pyreadstat

# Ruta del archivo .sav
path_to_sav_file = 'D:\ProyectosPracticos\PUCE\SEXTO SEMESTRE\IA\Proyecto IA\Codigo\.venv\EDG_1990_2021.sav'

# Ruta del archivo .csv de salida
path_to_csv_file = 'D:\ProyectosPracticos\PUCE\SEXTO SEMESTRE\IA\Proyecto IA\Codigo\.venv\EDG_1990_2021.csv'

# Leer el archivo .sav con pyreadstat
df, meta = pyreadstat.read_sav(path_to_sav_file, apply_value_formats=True, formats_as_category=True)

# Guardar el DataFrame en un archivo .csv
df.to_csv(path_to_csv_file, index=False)
"""
muestra.to_csv("muestraG6.csv", index=False)

# %%
dfMuestraG6 = pd.read_csv("muestraG6.csv")
dfMuestraG6
# Out:
#          prov_insc                        cant_insc  \
# 0        Pichincha  Distrito Metropolitano de Quito
# 1           Guayas                        Guayaquil
# 2       Chimborazo                         Riobamba
# 3           Manabí                            Chone
# 4        Pichincha  Distrito Metropolitano de Quito
# ...            ...                              ...
# 157562      Manabí                        Santa Ana
# 157563      Guayas                      Pedro Carbo
# 157564  Chimborazo                           Chambo
# 157565       Azuay                         Gualaceo
# 157566      El Oro                          Machala
#
#                                 parr_insc  anio_insc    mes_insc  dia_insc  \
# 0                                   Quito     2007.0       Abril       NaN
# 1                               Guayaquil     2011.0        Mayo       NaN
# 2                                   Licto     1996.0  Septiembre       NaN
# ...

# %% [markdown]
# # Se escogen los datos para el filtrado

# %%
dfCopia= dfMuestraG6
dfCopia
# Out:
#          prov_insc                        cant_insc  \
# 0        Pichincha  Distrito Metropolitano de Quito
# 1           Guayas                        Guayaquil
# 2       Chimborazo                         Riobamba
# 3           Manabí                            Chone
# 4        Pichincha  Distrito Metropolitano de Quito
# ...            ...                              ...
# 157562      Manabí                        Santa Ana
# 157563      Guayas                      Pedro Carbo
# 157564  Chimborazo                           Chambo
# 157565       Azuay                         Gualaceo
# 157566      El Oro                          Machala
#
#                                 parr_insc  anio_insc    mes_insc  dia_insc  \
# 0                                   Quito     2007.0       Abril       NaN
# 1                               Guayaquil     2011.0        Mayo       NaN
# 2                                   Licto     1996.0  Septiembre       NaN
# ...

# %% [markdown]
# ## Filtración de campos

# %%
dfCopia[["prov_insc", "cant_insc", "parr_insc", "sexo", "anio_nac","anio_fall","mes_fall","area_res","lc1"]].to_csv("muestraG6_limpio.csv", index=False)

# %%
dfMuestraLimpia = pd.read_csv("muestraG6_limpio.csv")
dfMuestraLimpia
# Out:
#           prov_insc                        cant_insc   parr_insc    sexo  \
# 0         Pichincha  Distrito Metropolitano de Quito       Quito   Mujer
# 1            Guayas                        Guayaquil   Guayaquil  Hombre
# 2        Chimborazo                         Riobamba       Licto   Mujer
# 3            Manabí                            Chone       Chone  Hombre
# 4         Pichincha  Distrito Metropolitano de Quito       Quito  Hombre
# ...             ...                              ...         ...     ...
# 396451     Imbabura                        Cotacachi     Imantag  Hombre
# 396452       Guayas                        Guayaquil  Rocafuerte  Hombre
# 396453   Tungurahua                           Ambato      Izamba   Mujer
# 396454  Santa Elena                      Santa Elena     Chanduy   Mujer
# 396455       Manabí                            Manta      Tarqui  Hombre
#
#         anio_nac  anio_fall    mes_fall area_res  \
# ...

# %%
dfMuestraLimpia.isnull().sum()
# Out:
# prov_insc      585
# cant_insc      585
# parr_insc      585
# sexo             0
# anio_nac         0
# anio_fall        0
# mes_fall         0
# area_res         0
# lc1          72810
# dtype: int64

# %% [markdown]
# ## Eliminamos valores Null del dataframe

# %%
df_limpio = dfMuestraLimpia.dropna(axis=0)
df_limpio
# Out:
#           prov_insc                        cant_insc   parr_insc    sexo  \
# 0         Pichincha  Distrito Metropolitano de Quito       Quito   Mujer
# 1            Guayas                        Guayaquil   Guayaquil  Hombre
# 3            Manabí                            Chone       Chone  Hombre
# 4         Pichincha  Distrito Metropolitano de Quito       Quito  Hombre
# 5         Pichincha  Distrito Metropolitano de Quito       Quito  Hombre
# ...             ...                              ...         ...     ...
# 396450        Cañar                          Azogues     Azogues  Hombre
# 396452       Guayas                        Guayaquil  Rocafuerte  Hombre
# 396453   Tungurahua                           Ambato      Izamba   Mujer
# 396454  Santa Elena                      Santa Elena     Chanduy   Mujer
# 396455       Manabí                            Manta      Tarqui  Hombre
#
#         anio_nac  anio_fall mes_fall area_res  \
# ...

# %% [markdown]
# ## Se comprueba que no haya nulos

# %%
df_limpio.isnull().sum()
# Out:
# prov_insc    0
# cant_insc    0
# parr_insc    0
# sexo         0
# anio_nac     0
# anio_fall    0
# mes_fall     0
# area_res     0
# lc1          0
# dtype: int64
